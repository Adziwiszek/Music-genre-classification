# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
import numpy as np 

class TrainEvalModels():
    def __init__(df, target):
    #     self.df=df
    #     self.target = target
    #     self.X_train = None
    #     self.X_test = None
    #     self.y_train = None
    #     self.y_test = None
    #     self.models_eval = {}

    # def split(test_size=0.2, random_state=42):
    #     X = df.drop([target])
    #     y = df[target]
    #     self.X_train, self.X_test, self.y_train, self.y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    def trainLinearSVC():
    

    def evaluate_model():
        # model_liner = LinearSVC(max_iter=10000)
        # model_liner.fit(X_train, y_train)
        # importances = model_liner.coef_[0] 
        
        # feat_importances = pd.Series(np.abs(model_liner.coef_[0]), index=X_train.columns)
        # top_features = feat_importances.nlargest(10).reset_index()
        # top_features.columns = ['Feature', 'Importance']
        # plt.figure(figsize=(10, 6))
        # sns.barplot(
        #     data=top_features, 
        #     x='Importance', 
        #     hue='Feature', 
        #     palette='viridis' 
        # )
        
        # plt.title("Top 10 Feature Importance (Linear SVM)", fontsize=15)
        # plt.xlabel("Coefficient Value (Importance)")
        # plt.ylabel("Features")
        # plt.show()
        
        # y_pred = model_liner.predict(X_test)
        # acc2 = accuracy_score(y_test, y_pred)
# Out:
#   Cell In[2], line 26
#     def evaluate_model()
#     ^
# IndentationError: expected an indented block after function definition on line 23
